# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import zipfile
# zip_path = '/content/drive/MyDrive/NLP_final/NLP_final.zip'
# data_dir = '/content/drive/MyDrive/NLP_final/'
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(data_dir)
# print("Đã giải nén:", data_dir)
# Out:
# Đã giải nén: /content/drive/MyDrive/NLP_final/

# %%
# !pip install transformers datasets sacrebleu  rouge-score evaluate --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.0 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done

# %%
import os
import math, time, glob, shutil, datetime
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from tqdm.auto import tqdm
from torch.optim import Adam
from transformers import PreTrainedTokenizerFast, get_linear_schedule_with_warmup
import evaluate

# ----- PATH CONFIG -----
BASE_PATH = '/content/drive/MyDrive/NLP_final/NLP_final'
RAW_DIR   = os.path.join(BASE_PATH, 'data', 'raw')
BPE_MODEL = os.path.join(BASE_PATH, 'tokenizer_bpe', 'model', 'tokenizer.json')
CHECKPOINT_DIR = os.path.join(BASE_PATH, 'ckpt_fs')
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
train_df = pd.read_csv(os.path.join(RAW_DIR, "train.csv"))
val_df   = pd.read_csv(os.path.join(RAW_DIR, "val.csv"))
test_df  = pd.read_csv(os.path.join(RAW_DIR, "test.csv"))
print("Train:", len(train_df), "Val:", len(val_df), "Test:", len(test_df))
display(train_df.head())
# Out:
# Train: 105685 Val: 13210 Test: 13211
#                                                   en  \
# 0  Cyrus sets up a model of how you run a great m...
# 1                   Solar 's wonderful on rooftops .
# 2  If we worry too much about some things , we en...
# 3  And they all kind of laughed and they patted h...
# 4  It was above the GDP for three years in a row ...
#
#                                                   vi  len_en_words  \
# 0  Cyrus xây dựng một mô hình chỉ cho ta cách điề...            18
# 1    Thái dương năng đầy uy lực nếu đặt trên mái cao             6
# 2  Nếu chúng ta lo lắng quá nhiều về một số thứ ,...            18
# 3  Và tất cả họ đều cười và vỗ nhẹ lên lưng anh ta .            14
# 4  Nó hơn cả GDP 3 năm liên tiếp ngay trước sự sụ...            16
#
#    len_vi_words
# 0            27
# 1            11
# 2            24
# 3            14
# 4            14

# %%
tokenizer = PreTrainedTokenizerFast(tokenizer_file=BPE_MODEL,
                                    bos_token='<s>', eos_token='</s>',
                                    pad_token='<pad>', unk_token='<unk>')
MAX_LEN = 128

# %%
def encode_pair(src, tgt):
    src_enc = tokenizer(src, max_length=MAX_LEN, truncation=True,
                        padding='max_length')
    tgt_ids = tokenizer.encode(tgt, add_special_tokens=False)
    tgt_ids = [tokenizer.bos_token_id] + tgt_ids + [tokenizer.eos_token_id]
    tgt_ids = tgt_ids[:MAX_LEN] + [tokenizer.pad_token_id]*(MAX_LEN-len(tgt_ids))

    # shift-right
    tgt_in  = tgt_ids[:-1]
    labels  = tgt_ids[1:]
    labels  = [tok if tok!=tokenizer.pad_token_id else -100 for tok in labels]

    return {"input_ids": src_enc["input_ids"],
            "attention_mask": src_enc["attention_mask"],
            "tgt_in": tgt_in,
            "labels": labels}

class TranslationDataset(Dataset):
    def __init__(self, df):
        self.samples = [encode_pair(r.en, r.vi) for _,r in df.iterrows()]
    def __len__(self): return len(self.samples)
    def __getitem__(self, idx):
        s = self.samples[idx]
        return {k: torch.tensor(v) for k,v in s.items()}

train_set = TranslationDataset(train_df)
val_set   = TranslationDataset(val_df)
test_set  = TranslationDataset(test_df)

train_loader = DataLoader(train_set, batch_size=8, shuffle=True)
val_loader   = DataLoader(val_set,   batch_size=8)
test_loader  = DataLoader(test_set,  batch_size=8)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=512):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        pos = torch.arange(max_len,dtype=torch.float).unsqueeze(1)
        div = torch.exp(torch.arange(0,d_model,2).float()*(-math.log(10000.0)/d_model))
        pe[:,0::2] = torch.sin(pos*div);  pe[:,1::2] = torch.cos(pos*div)
        self.register_buffer("pe", pe.unsqueeze(0))          # (1,L,d)

    def forward(self,x):  return x + self.pe[:,:x.size(1)]

class MultiHeadAttention(nn.Module):
    def __init__(self,d_model,h):
        super().__init__()
        assert d_model%h==0
        self.h, self.d_k = h, d_model//h
        self.q = nn.Linear(d_model,d_model)
        self.k = nn.Linear(d_model,d_model)
        self.v = nn.Linear(d_model,d_model)
        self.o = nn.Linear(d_model,d_model)
        self.scale = math.sqrt(self.d_k)

    def forward(self,q,k,v,mask=None):
        B,Tq,_ = q.size(); _,Tk,_ = k.size()
        def split(x):          # (B,T,d)->(B,h,T,d_k)
            return x.view(B,-1,self.h,self.d_k).transpose(1,2)
        q,k,v = map(split,(self.q(q),self.k(k),self.v(v)))
        scores = (q @ k.transpose(-2,-1)) / self.scale      # (B,h,Tq,Tk)
        if mask is not None:
            if mask.dim()==2: mask = mask[:,None,None,:]
            else:             mask = mask[:,None,:,:]
            scores = scores.masked_fill(mask==0, -1e9)
        attn = torch.softmax(scores,-1)
        out  = (attn @ v).transpose(1,2).contiguous().view(B,Tq,-1)
        return self.o(out)

class FeedForward(nn.Module):
    def __init__(self,d_model,d_ff,drop=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(d_model,d_ff), nn.ReLU(),
            nn.Linear(d_ff,d_model), nn.Dropout(drop))

    def forward(self,x): return self.net(x)

class EncoderLayer(nn.Module):
    def __init__(self,d,n_h,f,drop):
        super().__init__()
        self.sa = MultiHeadAttention(d,n_h)
        self.ff = FeedForward(d,f,drop)
        self.n1 = nn.LayerNorm(d); self.n2 = nn.LayerNorm(d)
        self.drop = nn.Dropout(drop)
    def forward(self,x,m):
        x = self.n1(x + self.drop(self.sa(x,x,x,m)))
        return self.n2(x + self.ff(x))

class DecoderLayer(nn.Module):
    def __init__(self,d,n_h,f,drop):
        super().__init__()
        self.sa = MultiHeadAttention(d,n_h)
        self.ca = MultiHeadAttention(d,n_h)
        self.ff = FeedForward(d,f,drop)
        self.n1 = nn.LayerNorm(d); self.n2 = nn.LayerNorm(d); self.n3 = nn.LayerNorm(d)
        self.drop = nn.Dropout(drop)
    def forward(self,x,enc,smask,tmask):
        x = self.n1(x + self.drop(self.sa(x,x,x,tmask)))
        x = self.n2(x + self.drop(self.ca(x,enc,enc,smask)))
        return self.n3(x + self.ff(x))

class Encoder(nn.Module):
    def __init__(self,vocab,d=512,N=4,h=8,f=2048,drop=0.1):
        super().__init__()
        self.emb = nn.Embedding(vocab,d)
        self.pos = PositionalEncoding(d)
        self.layers = nn.ModuleList([EncoderLayer(d,h,f,drop) for _ in range(N)])
        self.norm = nn.LayerNorm(d)
    def forward(self,src,mask):
        x = self.pos(self.emb(src))
        for l in self.layers: x = l(x,mask)
        return self.norm(x)

class Decoder(nn.Module):
    def __init__(self,vocab,d=512,N=4,h=8,f=2048,drop=0.1):
        super().__init__()
        self.emb = nn.Embedding(vocab,d)
        self.pos = PositionalEncoding(d)
        self.layers = nn.ModuleList([DecoderLayer(d,h,f,drop) for _ in range(N)])
        self.norm = nn.LayerNorm(d)
    def forward(self,tgt,enc,smask,tmask):
        x = self.pos(self.emb(tgt))
        for l in self.layers: x = l(x,enc,smask,tmask)
        return self.norm(x)

class TransformerScratch(nn.Module):
    def __init__(self,vocab,d=512,N=4,h=8,f=2048,drop=0.1):
        super().__init__()
        self.enc = Encoder(vocab,d,N,h,f,drop)
        self.dec = Decoder(vocab,d,N,h,f,drop)
        self.out = nn.Linear(d,vocab)

    def forward(self,src,tgt,smask,tmask):
        enc = self.enc(src,smask)
        return self.out(self.dec(tgt,enc,smask,tmask))

VOCAB = tokenizer.vocab_size
model  = TransformerScratch(VOCAB).to(DEVICE)
print("Model built")
# Out:
# Model built

# %%
# chính
num_epochs, accum, lr = 5, 4, 5e-4
VOCAB = tokenizer.vocab_size
optim  = optim.Adam(model.parameters(), lr=lr)
total  = (len(train_loader)//accum)*num_epochs
sched  = get_linear_schedule_with_warmup(optim, int(.1*total), total)
criterion = nn.CrossEntropyLoss(ignore_index=-100, label_smoothing=0.1)

best_val, patience, no_imp = 1e9, 1, 0

for ep in range(1, num_epochs+1):
    # -------- TRAIN LOOP --------
    model.train(); tr_loss = 0
    pbar = tqdm(train_loader, desc=f"Train {ep}/{num_epochs}")
    for i,b in enumerate(pbar,1):
        src, tgt_in, lab, sm = [b[k].to(DEVICE) for k in
            ("input_ids","tgt_in","labels","attention_mask")]
        B,S = tgt_in.shape
        pad_t = (tgt_in!=tokenizer.pad_token_id).unsqueeze(1)
        causal = torch.tril(torch.ones(S,S,device=DEVICE)).bool()
        tgt_m  = pad_t & causal

        logits = model(src, tgt_in, sm, tgt_m)
        loss  = criterion(logits.view(-1, VOCAB), lab.view(-1))/accum
        loss.backward(); tr_loss += loss.item()*accum
        if i%accum==0:
            optim.step(); sched.step(); optim.zero_grad()
        pbar.set_postfix(train_loss=f"{tr_loss/i:.4f}")

    # -------- VALIDATION LOOP --------
    model.eval(); val_loss = 0
    with torch.no_grad():
        for b in val_loader:
            src, tgt_in, lab, sm = [b[k].to(DEVICE) for k in
                ("input_ids","tgt_in","labels","attention_mask")]
            B,S = tgt_in.shape
            pad_t = (tgt_in!=tokenizer.pad_token_id).unsqueeze(1)
            causal = torch.tril(torch.ones(S,S,device=DEVICE)).bool()
            tgt_m  = pad_t & causal
            logits = model(src, tgt_in, sm, tgt_m)
            loss  = criterion(logits.view(-1, VOCAB), lab.view(-1))
            val_loss += loss.item()
    val_loss /= len(val_loader)
    print(f"Epoch {ep} | train_loss={tr_loss/len(train_loader):.4f} | val_loss={val_loss:.4f}")

    # -------- Save checkpoint tốt nhất --------
    torch.save(model.state_dict(), os.path.join(CHECKPOINT_DIR, f"epoch{ep:02d}.pt"))
    if val_loss < best_val:
        best_val = val_loss
        torch.save(model.state_dict(), os.path.join(CHECKPOINT_DIR, "best_model.pt"))
        no_imp = 0
    else:
        no_imp += 1
        if no_imp > patience:
            print("Early-stop"); break
# Out:
# Train 1/5:   0%|          | 0/13211 [00:00<?, ?it/s]
# Epoch 1 | train_loss=5.1728 | val_loss=4.2207
# Train 2/5:   0%|          | 0/13211 [00:00<?, ?it/s]
# Epoch 2 | train_loss=3.8561 | val_loss=3.7121
# Train 3/5:   0%|          | 0/13211 [00:00<?, ?it/s]
# Epoch 3 | train_loss=3.3707 | val_loss=3.4894
# Train 4/5:   0%|          | 0/13211 [00:00<?, ?it/s]
# Epoch 4 | train_loss=3.0051 | val_loss=3.3957
# Train 5/5:   0%|          | 0/13211 [00:00<?, ?it/s]
# Epoch 5 | train_loss=2.6783 | val_loss=3.3837

# %%
bleu  = evaluate.load("sacrebleu")
rouge = evaluate.load("rouge")

def greedy_decode(model,src,sm,max_len=128):
    model.eval()
    enc = model.enc(src,sm)
    ys  = torch.tensor([[tokenizer.bos_token_id]],device=src.device)
    for _ in range(max_len):
        S=ys.size(1)
        pad = (ys!=tokenizer.pad_token_id).unsqueeze(1)
        causal=torch.tril(torch.ones(S,S,device=src.device)).bool()
        tm = pad & causal
        logit = model.dec(ys,enc,sm,tm)
        nxt = model.out(logit)[:,-1,:].argmax(-1).item()
        ys  = torch.cat([ys, torch.tensor([[nxt]],device=src.device)],1)
        if nxt==tokenizer.eos_token_id: break
    return tokenizer.decode(ys[0,1:],skip_special_tokens=True).strip()

def eval_autoreg(loader, max_len=128):
    model.eval(); preds, refs = [], []
    for b in tqdm(loader,desc="Eval"):
        src,sm,lab = b["input_ids"].to(DEVICE), b["attention_mask"].to(DEVICE).bool(), b["labels"]
        for i in range(src.size(0)):
            preds.append(greedy_decode(model,src[i:i+1],sm[i:i+1],max_len))
            ref_ids=[tok if tok!=-100 else tokenizer.pad_token_id for tok in lab[i].tolist()]
            refs.append(tokenizer.decode(ref_ids,skip_special_tokens=True))
    bleu_score = bleu.compute(predictions=preds,references=[[r] for r in refs])['score']
    rouge_scores = rouge.compute(predictions=preds, references=refs)
    print("BLEU:", round(bleu_score,2))
    print("ROUGE-1:", round(rouge_scores['rouge1']*100,2))
    print("ROUGE-2:", round(rouge_scores['rouge2']*100,2))
    print("ROUGE-L:", round(rouge_scores['rougeL']*100,2))
    return preds, refs

# Đánh giá trên validation hoặc test
# Load best_model trước:
model.load_state_dict(torch.load(os.path.join(CHECKPOINT_DIR, "best_model.pt")))
preds, refs = eval_autoreg(val_loader,128)    # hoặc test_loader,128
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/8.15k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Eval:   0%|          | 0/1652 [00:00<?, ?it/s]
# WARNING:sacrebleu:That's 100 lines that end in a tokenized period ('.')
# WARNING:sacrebleu:It looks like you forgot to detokenize your test data, which may hurt your score.
# WARNING:sacrebleu:If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# BLEU: 24.96
# ROUGE-1: 68.41
# ROUGE-2: 44.14
# ROUGE-L: 59.0

# %%
def translate_batch(texts, model, tokenizer, device=DEVICE, max_len=128):
    model.eval()
    batch = tokenizer(texts, return_tensors="pt", padding=True, truncation=True, max_length=128).to(device)
    src_ids = batch['input_ids']
    src_mask = batch['attention_mask'].bool()
    translations = []
    for i in range(src_ids.size(0)):
        with torch.no_grad():
            enc_out = model.enc(src_ids[i:i+1], src_mask[i:i+1])
        ys = torch.tensor([[tokenizer.bos_token_id]], device=device)
        for _ in range(max_len):
            S = ys.size(1)
            tmask = torch.tril(torch.ones((S, S), dtype=torch.bool, device=device)).unsqueeze(0)
            with torch.no_grad():
                dec_out = model.dec(ys, enc_out, src_mask[i:i+1], tmask)
                logits = model.out(dec_out)
            next_token = logits[:, -1, :].argmax(-1).item()
            ys = torch.cat([ys, torch.tensor([[next_token]], device=device)], dim=1)
            if next_token == tokenizer.eos_token_id:
                break
        out_ids = ys[0, 1:].tolist()
        translations.append(tokenizer.decode(out_ids, skip_special_tokens=True).strip())
    return translations

sample_en = [
    "I want to go to sleep",
    "I ate apple yesterday",
    "Good morning! Did you sleep well?",
    "Yesterday the stock market plunged almost five percent.",
    "She wonders whether artificial intelligence will ever surpass human creativity.",
    "Please, turn off the lights before you leave the laboratory.",
    "Although it rained heavily, the concert continued until midnight.",
    "The report, which was published in 2023, estimates that global CO₂ emissions hit 37.4 gigatons.",
    "Have you ever tried Vietnamese egg coffee?",
    "If we fail to act now, future generations will pay the price.",
    "NASA's James Webb telescope recently captured breathtaking images of distant galaxies.",
    "In my opinion, learning a new language is like opening an extra window on the world."
]

vi_translations = translate_batch(sample_en, model, tokenizer, device=DEVICE, max_len=128)
print("\n--- Sample Translations ---")
for en, vi in zip(sample_en, vi_translations):
    print(f"EN: {en}\nVI: {vi}\n")
# Out:
# --- Sample Translations ---
# EN: I want to go to sleep
# VI: Tôi muốn đi ngủ để ngủ để ngủ .
#
# EN: I ate apple yesterday
# VI: Tôi ăn táo hôm qua ngày hôm qua ăn táo vào ngày hôm qua tôi ăn táo .
#
# EN: Good morning! Did you sleep well?
# VI: Chào buổi sáng , bạn ngủ ngon lành bạn nghỉ hưu tốt cho bạn nghỉ hưu giấc ngủ ngon lành bạn có thể làm bạn vui vẻ
#
# EN: Yesterday the stock market plunged almost five percent.
# VI: Có thị trường chứng khoán giảm gần 5 %
#
# EN: She wonders whether artificial intelligence will ever surpass human creativity.
# VI: Cô ấy tự hào cho dù trí tuệ nhân tạo có thể vượt qua sự sáng tạo của con người .
#
# EN: Please, turn off the lights before you leave the laboratory.
# VI: Xin hãy tắt đèn chiếu sáng trước khi bạn rời phòng thí nghiệm
#
# EN: Although it rained heavily, the concert continued until midnight.
# VI: Mặc dù nó đã làm hoà nhạc cho đến tận nửa đêm .
#
# EN: The report, which was published in 2023, estimates that global CO₂ emissions hit 37.4 gigatons.
# VI: Báo cáo của báo cáo được xuất bản vào năm 20,000 ước tính toàn cầu hoá khí cầu đánh giá khí thải khí thải tổng thống 374.4.
#
# EN: Have you ever tried Vietnamese egg coffee?
# VI: Bạn đã từng thử cà phê cà phê cà phê cà phê Việt Nam
#
# EN: If we fail to act now, future generations will pay the price.
# VI: Nếu chúng ta thất bại trong tương lai sẽ trả giá cho giá của bạn .
#
# EN: NASA's James Webb telescope recently captured breathtaking images of distant galaxies.
# VI: Gần đây , kính viễn vọng của James đã chụp được hình ảnh từ những thiên hà xa xôi .
#
# EN: In my opinion, learning a new language is like opening an extra window on the world.
# VI: Theo tôi , trong ý kiến của tôi , học một ngôn ngữ mới giống như một cái cửa sổ trên thế giới .

# %%
from torch.utils.data import DataLoader, Subset
import random

n_samples = 100
indices = random.sample(range(len(val_set)), n_samples)
sample_set = Subset(val_set, indices)
sample_loader = DataLoader(sample_set, batch_size=1, shuffle=False)

# %%
def beam_decode(model, src, sm, tokenizer, beam_width=5, max_len=128, device=DEVICE):
    model.eval()
    with torch.no_grad():
        enc = model.enc(src, sm)
        # Mỗi phần tử beam: (sequence tensor, score)
        beams = [(torch.tensor([[tokenizer.bos_token_id]], device=device), 0.0)]
        completed = []

        for _ in range(max_len):
            new_beams = []
            for seq, score in beams:
                S = seq.size(1)
                pad = (seq != tokenizer.pad_token_id).unsqueeze(1)
                causal = torch.tril(torch.ones(S, S, device=device)).bool()
                tm = pad & causal
                dec_out = model.dec(seq, enc, sm, tm)
                logits = model.out(dec_out)
                log_probs = torch.log_softmax(logits[:, -1, :], dim=-1)
                topk_log_probs, topk_ids = log_probs.topk(beam_width)

                for k in range(beam_width):
                    next_token = topk_ids[0, k].item()
                    next_score = score + topk_log_probs[0, k].item()
                    new_seq = torch.cat([seq, torch.tensor([[next_token]], device=device)], dim=1)
                    if next_token == tokenizer.eos_token_id:
                        completed.append((new_seq, next_score))
                    else:
                        new_beams.append((new_seq, next_score))
            # Giữ lại beam_width sequence có score tốt nhất
            beams = sorted(new_beams, key=lambda x: x[1], reverse=True)[:beam_width]
            if len(beams) == 0:
                break

        # Nếu có completed sequence, lấy score cao nhất
        if completed:
            best_seq = sorted(completed, key=lambda x: x[1], reverse=True)[0][0]
        else:
            best_seq = beams[0][0]

        return tokenizer.decode(best_seq[0, 1:], skip_special_tokens=True).strip()

# %%
def eval_beam_autoreg(loader, beam_width=5, max_len=128):
    model.eval(); preds, refs = [], []
    for b in tqdm(loader, desc=f"Eval Beam{beam_width}"):
        src, sm, lab = b["input_ids"].to(DEVICE), b["attention_mask"].to(DEVICE).bool(), b["labels"]
        pred = beam_decode(model, src, sm, tokenizer, beam_width=beam_width, max_len=max_len, device=DEVICE)
        preds.append(pred)
        ref_ids = [tok if tok != -100 else tokenizer.pad_token_id for tok in lab[0].tolist()]
        refs.append(tokenizer.decode(ref_ids, skip_special_tokens=True))
    bleu_score = bleu.compute(predictions=preds, references=[[r] for r in refs])['score']
    rouge_scores = rouge.compute(predictions=preds, references=refs)
    print(f"BLEU (beam{beam_width}):", round(bleu_score, 2))
    print("ROUGE-1:", round(rouge_scores['rouge1'] * 100, 2))
    print("ROUGE-2:", round(rouge_scores['rouge2'] * 100, 2))
    print("ROUGE-L:", round(rouge_scores['rougeL'] * 100, 2))
    return preds, refs

# Chạy đánh giá
preds_beam, refs_beam = eval_beam_autoreg(sample_loader, beam_width=5, max_len=128)
# Out:
# Eval Beam5:   0%|          | 0/100 [00:00<?, ?it/s]
# BLEU (beam5): 24.21
# ROUGE-1: 67.66
# ROUGE-2: 43.63
# ROUGE-L: 58.37

# %%
en_samples = [val_df.iloc[idx]['en'] for idx in indices] 

for i, (en, hyp, ref) in enumerate(zip(en_samples, preds_beam, refs_beam)):
    print(f"[{i+1}]")
    print("EN :", en)
    print("Pred:", hyp)
    print("Ref :", ref)
    print("-" * 40)
# Out:
# [1]
# EN : We are still asking the question .
# Pred: Chúng ta vẫn đang hỏi câu hỏi .
# Ref : Còn chúng ta vẫn đang đặt ra những câu hỏi .
# ----------------------------------------
# [2]
# EN : In fact , one of the most important was a brain region that becomes active when you feel the rush of cocaine .
# Pred: Trên thực tế , một trong những phần quan trọng nhất là một khu vực não hoạt động khi bạn cảm thấy chất lỏng đi .
# Ref : Thực ra , một trong những điều quan trọng nhất là một khu vực não bộ khu vực ấy trở nên hoạt động tích cực mà bạn cảm thấy có sự xuất hiện đột ngột của cocaine
# ----------------------------------------
# [3]
# EN : He was a brilliant scientist at the frontiers of mathematics , even as a teenager .
# Pred: Ông ấy là một nhà khoa học thông minh về toán học , thậm chí là một thiếu niên .
# Ref : Ông là một nhà khoa học vĩ đại đạt tới đỉnh cao của toàn học ngay từ thời niên thiếu
# ----------------------------------------
# [4]
# EN : Stress hormones , glucocorticoids , released by the brain , suppress the growth of these new cells .
# Pred: Những hóc môn này đã phát sinh ra mê cung , do não tăng trưởng của các tế bào mới .
# Ref : Những hormone stress , glucocorticoids , do não giải phóng , triệt tiêu sự phát triển của những tế bào mới này .
# ----------------------------------------
# [5]
# EN : But that 's no longer an accurate depiction of plastic pollution in the marine environment .
# Pred: Nhưng đó không phải là một sự việc chính xác về việc ô nhiễm chất dẻo trong môi trường biển .
# Ref : Nhưng đó không còn là sự miêu tả chính xác về ô nhiễm đồ nhựa trong môi trường biển .
# ----------------------------------------
# [6]
# EN : So it took about 24 hours to get this line .
# Pred: Vì vậy , mất khoảng 24 giờ để đạt được dòng này .
# Ref : Mất 24 giờ để tạo được đường này .
# ----------------------------------------
# [7]
# EN : Okay .
# Pred: Được rồi .
# Ref : Ok .
# ----------------------------------------
# [8]
# EN : But I was still concerned , so I said , " You know what , I 'm not going to do it . "
# Pred: Nhưng tôi vẫn còn lo lắng , nên tôi nói , " Anh biết không , tôi sẽ không làm được . "
# Ref : Nhưng tôi vẫn còn thắc mắc , nên tôi hỏi , " Ông biết không , tôi sẽ không làm việc đó đâu . "
# ----------------------------------------
# [9]
# EN : Because you have to chuck out masses and masses of it , hoping that your sex cells , your male sex cells , which are held within the pollen , will somehow reach another flower just by chance .
# Pred: Bởi vì bạn phải phân chia những khối lượng và sự sống , hy vọng rằng các tế bào giới tính của bạn , những tế bào đực của bạn , được tổ chức trong phấn hoa , bằng cách nào đó sẽ chạm tới một bông hoa khác .
# Ref : Bởi vì bạn phải tống ra hàng đống hàng đống hạt phấn , với hi vọng rằng những tế bào giới tính , những tế bào giới tính đực của bạn , chứa trong hạt phấn , bằng một cách nào đó sẽ đến được những bông hoa khác một cách tình cờ .
# ----------------------------------------
# [10]
# EN : You practice ancient Balinese arts .
# Pred: Bạn luyện tập những nghệ thuật cổ đại .
# Ref : Được học về những môn nghệ thuật của người Bali cổ .
# ----------------------------------------
# [11]
# EN : We had a financial regulatory regime based on the assumptions that traders were rational creatures who wouldn 't do anything stupid .
# Pred: Chúng tôi có một chế độ tài chính dựa trên những giả định mà các nhà sinh vật lý học không làm gì cả .
# Ref : Chúng ta sở hữu 1 chế độ luật lệ tài chính dựa trên những giả định mà những nhà giao dịch là những sinh vật có lý trí những người sẽ không làm gì ngu ngốc cả .
# ----------------------------------------
# [12]
# EN : So here 's an example of how we did it .
# Pred: Đây là một ví dụ về cách chúng tôi đã làm .
# Ref : Vậy đây là một ví dụ về cách chúng tôi đã làm
# ----------------------------------------
# [13]
# EN : And in poorer countries , smaller countries , fragile countries , conflict-afflicted countries , remittances are a lifeline , as in Somalia or in Haiti .
# Pred: Và ở những nước nghèo , các nước nhỏ hơn , những quốc gia nhỏ hơn , xung đột giữa các quốc gia , kiều hối là những quốc gia nhập cư , như ở Somalia hay ở Haiti .
# Ref : Và ở những nước nghèo hơn , nhỏ hơn , bất ổn , các nước bị ảnh hưởng xung đột , kiều hối là cứu sinh , như trường hợp của Somalia hay Haiti .
# ----------------------------------------
# [14]
# EN : But , steady state doesn 't mean that things are getting better , it 's just that they have stopped getting worse .
# Pred: Nhưng , một bang không có nghĩa là mọi thứ đang ngày càng trở nên tốt hơn , chúng chỉ dừng lại một cách tồi tệ hơn .
# Ref : Nhưng , tình trạng ổn định không có nghĩa là mọi thứ đang chuyển biến tốt lên , mà chỉ là đang không xấu đi thôi .
# ----------------------------------------
# [15]
# EN : So there isn 't a big legacy in the pride of education .
# Pred: Vì thế không phải là một di sản lớn trong giáo dục tự hào .
# Ref : Đây không phải là một sự kế thừa lớn trong nền giáo dục hiện đại .
# ----------------------------------------
# [16]
# EN : Well , right , it is a good thing to do , but you have to think what else you could do with the resources .
# Pred: Vâng , đúng là một điều tốt để làm , nhưng bạn phải nghĩ gì khác bạn có thể làm với các nguồn tài nguyên .
# Ref : Vâng , đúng vậy , đó là một việc tốt , nhưng cần nghĩ rằng bạn còn có thể làm được những gì khác nữa với các nguồn tài nguyên .
# ----------------------------------------
# [17]
# EN : Frustrated by this myopic view , my friend and I had this crazy idea : Let 's break our fast at a different mosque in a different state each night of Ramadan and share those stories on a blog .
# Pred: Người đàn ông : Hãy nhìn vào quan điểm của tôi , bạn tôi và tôi có ý tưởng điên rồ này : Hãy nghỉ ngơi tại một nhà thờ Hồi giáo khác nhau trong một nhà thờ ở Ramadan và chia sẻ những câu chuyện trên blog .
# Ref : Tức giận bởi tầm nhìn hạn hẹp đó , tôi và người bạn đã nảy ra một ý tưởng điên rồ : Bắt đầu tháng ăn chay truyền thống ở một nhà thờ Hồi Giáo ở mỗi bang vào mỗi đêm của tháng Ramadan rồi chia sẻ câu chuyện đó lên blog .
# ----------------------------------------
# [18]
# EN : As we speak , there are 117 or so clinical trials researching the use of stem cells for liver diseases .
# Pred: Như chúng ta đã nói , có những thử nghiệm lâm sàng hoặc những thử nghiệm lâm sàng sử dụng tế bào gốc của gan .
# Ref : Khi ta đang nói chuyện đây , có chừng 117 ca thử nghiệm phòng khám nghiên cứu việc sử dụng tế bào gốc cho các bệnh gan .
# ----------------------------------------
# [19]
# EN : And it brought me into contact with volunteers and helpers .
# Pred: Và nó mang tôi đến với tình nguyện viên và giúp đỡ .
# Ref : Và nó mang lại cho tôi sự tiếp xúc với nhiều người tình nguyện và người hỗ trợ .
# ----------------------------------------
# [20]
# EN : Now as a closing thought , I believe we 're actually in a period where we 're waking up from this humongous hangover of emptiness and waste , and we 're taking a leap to create a more sustainable system built to serve our innate needs for community and individual identity .
# Pred: Bây giờ , khi kết thúc , tôi tin rằng chúng ta thực sự đang ở trong một khoảng thời gian mà chúng ta đang thức dậy từ nơi mà chúng ta đang thức dậy khỏi sự phun trào lưu và lãng phí và lãng phí , và chúng ta đang tiến hành một hệ thống bền vững hơn để phục vụ cộng đồng của chúng ta và tự tạo ra bản sắc cá nhân của riêng mình .
# Ref : Bây giờ như là một suy nghĩ kết thúc ở đây Tôi tin rằng chúng ta đang trong giai đoạn khi mà chúng ta tỉnh dậy sau cái cơn say rượu mệt mỏi của sự trống rỗng và phí phạm , và chúng ta sẽ có một bước nhảy vọt để tạo ra một hệ thống bền vững hơn xây dựng để phục vụ những du cầu bẩm sinh của chúng ta cho cộng đồng và bản sắc cá nhân .
# ----------------------------------------
# [21]
# EN : And it 's not that he 's not eating , it 's that when he eats , his intestine basically opens up and feces spill out into his gut .
# Pred: Và nó không phải là ông ta không ăn , mà là khi ông ta ăn , những chất xơ cơ bản của ông ta mở ra và tràn vào ruột .
# Ref : Không phải là do nó không ăn gì , mà là khi cậu bé ăn , dạ dày cơ bản là mở rộng ra và phân trào ra tràn vào ruột của nó .
# ----------------------------------------
# [22]
# EN : But what 's important in this picture is that you have a piece of multi-year ice , that big chunk of ice up in the corner .
# Pred: Nhưng điều quan trọng trong bức ảnh này là bạn có một mảng băng đa của năm , đó là một phần lớn của tảng băng .
# Ref : Nhưng điểm quan trọng trong bức hình này là bạn thấy một mảng băng nhiều năm tuổi là núi băng lớn ở phía góc .
# ----------------------------------------
# [23]
# EN : It 's an amazing experience .
# Pred: Đó là một trải nghiệm tuyệt vời .
# Ref : Nó là một trải nghiệm tuyệt vời .
# ----------------------------------------
# [24]
# EN : And , in fact , it 's the best evidence we have to date for not only existence of a supermassive black hole at the center of our own galaxy , but any in our universe .
# Pred: Trên thực tế , đó là bằng chứng tốt nhất chúng ta phải hẹn hò không chỉ tồn tại một siêu lỗ đen tại trung tâm thiên hà của chúng ta , mà trong vũ trụ của chúng ta .
# Ref : và , thực tế , nó là bằng chứng tốt nhất chúng ta có cho đến nay cho không chỉ sự tồn tại của siêu lỗ đen ở trung tâm giải Ngân hà của chúng ta , mà còn trong toàn vũ trụ .
# ----------------------------------------
# [25]
# EN : You know , cats falling . Cats do this . They twist their bodies .
# Pred: Các bạn biết không , mèo giảm đi . Cáo cơ thể .
# Ref : Bạn biết đấy , khi mèo rơi , chúng làm như thế này . Chúng vặn người .
# ----------------------------------------
# [26]
# EN : So I am here today because I think we need hackers , and in fact , they just might be the immune system for the information age .
# Pred: Tôi ở đây hôm nay vì chúng ta cần những hacker , và thực tế , chúng có thể là hệ thống miễn dịch cho thông tin .
# Ref : Tôi ở đây hôm nay bởi vì tôi nghĩ ta cần đến các hacker , và họ có thể là hệ miễn dịch cho thời đại thông tin .
# ----------------------------------------
# [27]
# EN : The moment I say " school , " so many memories come back to me .
# Pred: Khoảnh khắc tôi nói " ngôi trường , rất nhiều ký ức quay lại với tôi .
# Ref : Khi tôi nói " trường học " có quá nhiều kỷ niệm trở về trong tôi .
# ----------------------------------------
# [28]
# EN : So armed with this information from the LHC , together with some colleagues here at CERN , we computed the probability that our universe could quantum tunnel into the ultra-dense Higgs state , and we found a very intriguing result .
# Pred: Vì vậy , với thông tin này từ LHC , cùng với một số đồng nghiệp ở đây , chúng tôi đã ghi nhận lại khả năng xác định vũ trụ của chúng ta có thể thâm nhập vào trạng thái siêu vi khuẩn , và chúng tôi đã tìm ra kết quả rất thú vị .
# Ref : Vậy với thông tin này từ LHC , cùng với các đồng nghiệp ở CERN , chúng tôi đã tính toán xác suất mà vũ trụ chúng ta có thể dùng đường hầm lượng tử chuyển thành trạng thái Higgs siêu đặc , và chúng tôi đã tìm thấy một kết quả rất thú vị
# ----------------------------------------
# [29]
# EN : In three weeks , maybe three and a half , I had 46,000 signatures on this petition .
# Pred: Trong ba tuần , có thể ba và một nửa , tôi đã có 46,000 bộ phận tư tưởng này .
# Ref : Trong vòng 3 tuần , có lẽ là 3 tuần rưỡi Tôi đã có được 46 ngàn chữ kí ủng hộ .
# ----------------------------------------
# [30]
# EN : SK : We now have on the order of 2,200 videos covering everything from basic arithmetic all the way to vector calculus and some of the stuff you saw there .
# Pred: SK : hiện nay chúng ta đang có trên trật tự 2.20000 video từ tất cả các hướng dẫn để giải tích và vài thứ mà bạn thấy ở đó .
# Ref : SK : Đến thời điểm này chúng tôi đã có khoảng 2,200 video bao gồm tất cả các môn học từ số học cơ bản đến giải tích véc tơ và một vài thứ bạn thấy ở đây .
# ----------------------------------------
# [31]
# EN : She replied , " Posture . My back is always straight , and I don 't make old people 's noises . "
# Pred: Cô ấy trả lời , " Những món quà của tôi luôn thẳng thắn , và tôi không làm tiếng ồn của mọi người . "
# Ref : Bà trả lời , " Tư thế . Lưng của tôi luôn luôn thẳng , và tôi không phát ra âm thanh của người già . "
# ----------------------------------------
# [32]
# EN : And you wouldn 't believe it , but the one after that is going to be called The Overwhelmingly Large Telescope .
# Pred: Và bạn sẽ không tin được , nhưng sau một điều sau đó sẽ được gọi là The Guardian những cái gọi là The Economistelly .
# Ref : và bạn sẽ không tin tôi nhưng mà cái kính tiếp theo sẽ được gọi là Kính Viễn Vọng Cực Kỳ Lớn .
# ----------------------------------------
# [33]
# EN : Nobel Peace laureate Jody Williams brings tough love to the dream of world peace , with her razor-sharp take on what " peace " really means , and a set of profound stories that zero in on the creative struggle -- and sacrifice -- of those who work for it .
# Pred: Bình luận hoà bình thế giới , Jody Williams đưa tình yêu đến giấc mơ của hoà bình thế giới , với sự bùng nổ của cô ấy , mang lại những gì " hoà bình " có nghĩa là " và một tập hợp những câu chuyện sâu sắc về không có trong đấu tranh về sự sáng tạo -- và hy sinh những người làm việc đó .
# Ref : Người Đoạt giải Nobel Hoà Bình , Jody Williams , mang đến tình yêu khó khăn đến hoà bình thế giới , với cái nhìn sắc nét của cô ấy về ý nghĩa thực sự của " hoà bình " , và một bộ những câu truyện sâu sắc rằng không ở trên cuộc đấu tranh sáng tao -- và sự hi sinh -- của những ai làm việc cho nó .
# ----------------------------------------
# [34]
# EN : And one of the first things that surprised me when I got on board Kendal was , where are all the people ?
# Pred: Và một trong những điều đầu tiên làm tôi ngạc nhiên khi lên tàu Kendal là ai ?
# Ref : Và một trong những điều đầu tiên làm tôi ngạc nhiên khi đến Kendal là , mọi người đâu cả rồi ?
# ----------------------------------------
# [35]
# EN : In other words , my value was once ensured by submitting myself to the traditional authorities .
# Pred: Nói cách khác , giá trị của tôi đã từng được đảm bảo bởi chính bản thân tôi với chính quyền truyền thống .
# Ref : Nói cách khác , ngày xưa giá trị của tôi được đảm bảo bằng việc tuân thủ những luật lệ truyền thống
# ----------------------------------------
# [36]
# EN : " [ Imitating Arabic ] -- Tutti Frutti ! "
# Pred: " [ yêu thích tiếng Ả Rập ] -- Tutaka -- "
# Ref : " [ bắt chước tiếng Ả rập ] -- Tutti Frutti ! "
# ----------------------------------------
# [37]
# EN : They have to gamble , because they want to appear cutting edge and catch the words that are going to make it , such as LOL , but they don 't want to appear faddish and include the words that aren 't going to make it , and I think a word that they 're watching right now is YOLO , you only live once .
# Pred: Họ phải đánh cược , bởi vì họ muốn xuất hiện ở mép và bắt kịp các từ sẽ biến nó thành , như là LOL , nhưng họ không muốn xuất hiện một cách xuất hiện và bao gồm những từ mà sẽ không tạo ra , và tôi nghĩ rằng đó là một từ mà họ đang theo dõi ngay bây giờ , bạn chỉ muốn sống một lần .
# Ref : Họ phải liều đánh cuộc , vì họ muốn mạo hiểm bắt con mồi và tóm được từ rồi sẽ thành thông dụng , như LOL , đồng thời họ không muốn thành gàn dở thêm vào các từ không sống nổi qua đêm , tôi thấy một từ họ đang đưa vào tầm ngắm là YOLO , you only live once .
# ----------------------------------------
# [38]
# EN : Well , ultimately , it could mean that you could print your own medicine .
# Pred: Cuối cùng , điều đó có nghĩa là bạn có thể in thuốc của mình .
# Ref : Vâng , cuối cùng , nó có nghĩa rằng bạn có thể in ra loại thuốc của riêng bạn .
# ----------------------------------------
# [39]
# EN : So we can 't relate to her . And when you can 't relate to somebody , you don 't envy them .
# Pred: Vì thế chúng tôi không thể liên hệ với bà . Và khi bạn không thể liên hệ với ai đó , bạn không ghen tị với họ .
# Ref : Và chúng ta không liên quan đến bà . Và khi chúng ta không liên quan đến ai đó , chúng ta không ghen tị với họ .
# ----------------------------------------
# [40]
# EN : PM : So when we first started talking about , maybe the subject wouldn 't be social media , which we assumed it would be , but that you had very much on your mind the missing leadership positions , particularly in the sector of technology and social media .
# Pred: PM : Khi chúng tôi bắt đầu nói về vấn đề này , có lẽ là không phải là phương tiện truyền thông xã hội , mà chúng tôi cho rằng nó sẽ là , nhưng bạn đã có nhiều suy nghĩ về vị trí lãnh đạo , đặc biệt trong lĩnh vực công nghệ và truyền thông xã hội .
# Ref : PM : Lần đầu chúng ta nói chuyện , chủ đề không phải là về truyền thông xã hội , mà về lĩnh vực chị đã có nhiều kiến thức và kinh nghiệm sự thiếu vắng những vị trí lãnh đạo , trong công nghệ và truyền thông xã hội .
# ----------------------------------------
# [41]
# EN : The first thing we usually do when someone disagrees with us is we just assume they 're ignorant .
# Pred: Điều đầu tiên mà chúng ta thường làm khi ai đó nói chuyện với chúng ta là chúng ta giả định rằng chúng là một người không biết .
# Ref : Điều đầu tiên mà chúng ta làm khi có ai đó bất đồng với chúng ta là chúng ta cho rằng họ không biết gì hết .
# ----------------------------------------
# [42]
# EN : The real hat trick for this vehicle , though , is a disruptive new navigation system we 've developed , known as 3D SLAM , for simultaneous localization and mapping .
# Pred: Cái mũ thực sự cho phương pháp này , mặc dù , là một hệ thống định vị mới mà chúng ta đã phát triển , được biết đến như là 3D SLMA , cho các vũ khí địa phương và lập bản đồ .
# Ref : Hattrick thực sự của robot này , mặc dù , là hệ thống điều hướng phân rã mà chúng tôi phát triển , gọi là 3D SLAM , dùng cho công việc đồng thời định vị và lập bản đồ .
# ----------------------------------------
# [43]
# EN : Because we need an international legal framework for robotic weapons .
# Pred: Bởi vì chúng ta cần một khuôn khổ quốc tế cho vũ khí rô-bốt .
# Ref : Vì chúng ta cần một khung pháp lý quốc tế đối với vũ khí rô-bốt .
# ----------------------------------------
# [44]
# EN : At the top , you see the New Criminal Activity Score , six of course being the highest , and then in the middle you see , " Elevated risk of violence . "
# Pred: Bên trên cùng , bạn thấy Đạo luật của New York đã được bảo vệ bởi 6 người dân số cao nhất , và sau đó ở giữa bạn thấy , " Sự mạo hiểm của bạo lực . "
# Ref : Trên cùng , bạn thấy tỷ lệ phạm tội mới , thang sáu là cao nhất , và ở giữa bạn thấy " mức độ bạo lực nâng cao . "
# ----------------------------------------
# [45]
# EN : And I present to you a concept that these are extended neurological membranes .
# Pred: Và tôi trình bày cho các bạn một khái niệm rằng đây là những nhân vật thần kinh gây ra .
# Ref : Và tôi cho các bạn biết một khái niệm mới , chúng là những màng tế bào thần kinh nối dài .
# ----------------------------------------
# [46]
# EN : By expressing it as an if-then statement , you can get the message across without appearing to boss another person around .
# Pred: Bằng cách nói về nó như là một tuyên bố nếu bạn có thể có thông điệp qua việc không có cách nào để sếp lên người khác .
# Ref : Bằng cách diễn đạt mong muốn đó dưới dạng câu " nếu-thì " , bạn có thể yêu cầu người ta mà không tỏ ra mình đang sai khiến người ta .
# ----------------------------------------
# [47]
# EN : I think that exchange can actually get in the way of the very thing that we want most .
# Pred: Tôi nghĩ sự trao đổi đó có thể thực sự có được cách mà chúng ta muốn nhất .
# Ref : Tôi nghĩ là sự trao đổi này có thể ngăn cản điều chúng ta mong muốn .
# ----------------------------------------
# [48]
# EN : Now , there is actually a little origami in the James Webb Space Telescope , but it 's very simple .
# Pred: Bây giờ , thực ra có một hình origami nhỏ ở Đại Tây Dương , nhưng nó rất đơn giản .
# Ref : Bây giờ , thật ra có một chút origami trong Kính Viễn Vọng James Webb , nhưng nó rất đơn giản .
# ----------------------------------------
# [49]
# EN : That means it 's completely remixable . It also means there 's no proprietary software . All you need is a web browser .
# Pred: Điều đó có nghĩa là hoàn toàn có thể hoà nhập
# Ref : Điều đó có nghĩa là nó là hoàn toàn có thể remix . Nó cũng có nghĩa là không có phần mềm độc quyền . Tất cả những gì bạn cần là một trình duyệt web .
# ----------------------------------------
# [50]
# EN : Every time there was a new , fast machine , he started using it , and saw exactly what 's happening now .
# Pred: Mỗi khi có một cỗ máy mới , anh ấy bắt đầu sử dụng nó , và thấy chính xác những gì đang xảy ra .
# Ref : Mỗi khi có 1 cỗ máy mới tốc độ nhanh , ông lại bắt đầu sử dụng nó , và thấy được chính xác điều gì đang diễn ra :
# ----------------------------------------
# [51]
# EN : And they don 't care whether or not Geoff is upset he can 't go to the bank . Go find another bank .
# Pred: Và họ không quan tâm tới việc có hay không bị tổn thương không khó chịu đến mức ông ta không thể đến ngân hàng . Hãy tìm một ngân hàng khác .
# Ref : Và họ cũng chẳng quan tâm có phải Geoff đang buồn bã hay không nếu anh ta không thể đến ngân hàng đó , vậy thì đi tìm một ngân hàng khác .
# ----------------------------------------
# [52]
# EN : This empire is , in fact , the Middle East as we now know it , and it 's what shapes the Middle East as we now know it .
# Pred: Thực tế là , Trung Đông hiện nay như chúng ta biết , và đó là hình dáng Trung Đông mà chúng ta biết .
# Ref : Đế chế này , trên thực tế , là toàn bộ Trung Đông như chúng ta biết ngày nay , và chính nó đã hình thành Trung Đông như ta đã biết .
# ----------------------------------------
# [53]
# EN : We 've started many programs just to make sure that the child comes to school .
# Pred: Chúng tôi bắt đầu nhiều chương trình để chắc chắn rằng đứa trẻ đến trường .
# Ref : Chúng tôi đã mở rất nhiều chương trình để đảm bảo rằng những đứa trẻ được đi học .
# ----------------------------------------
# [54]
# EN : The German magazine Stern , a news magazine , had its app censored because the Apple nannies deemed it to be a little bit too racy for their users , and despite the fact that this magazine is perfectly legal for sale on newsstands throughout Germany .
# Pred: Tạp chí Người Đức , một tạp chí , đã có một ứng dụng bởi vì Apple sư Apple , nó trở thành một phần nhỏ đối với người dùng , và mặc dù rằng tạp chí này hoàn toàn phù hợp với tin tức ở Đức .
# Ref : Một tạp chí tin tức của Đức , Stern , đã có những ứng dụng bị loại bỏ bởi vì bộ phận chăm sóc khách hàng của Apple cho rằng nó có một chút gì đó bất bình thường đối với người sử dụng bất chấp thực tế rằng đây là một tạp chí hợp hoàn toàn hợp pháp để bán ở các sạp báo trên toàn nước Đức .
# ----------------------------------------
# [55]
# EN : So the first project , which will be built next summer , is an open-air farmers ' market downtown , followed by bus shelters for the school bus system in the second year and home improvements for the elderly in the third year .
# Pred: Dự án đầu tiên , được xây dựng vào mùa hè , là một nông dân mở thị trường trung tâm thành phố , theo sau xe buýt cho hệ thống xe buýt vào hệ thống xe buýt vào năm thứ hai cho người già .
# Ref : Và dự án đầu tiên , xây dựng vào mùa hè tới , sẽ là một khu chợ ngoài trời ở trung tâm thành phố , tiếp theo là những bến xe buýt có mái cho cho hệ thống xe buýt trường học năm thứ hai và dự án nâng cấp nhà cửa cho người cao tuổi vào năm thứ ba .
# ----------------------------------------
# [56]
# EN : In India we often love to complain about our government bodies .
# Pred: Ở Ấn Độ , chúng ta thường thích phàn nàn về chính phủ của mình .
# Ref : Ở Ấn Độ , chúng tôi thường thích than vãn về nhà nước .
# ----------------------------------------
# [57]
# EN : The what now was not to mirror the mind of God , but to follow the emotion turbulence of man .
# Pred: Điều mà bây giờ không phản chiếu tâm trí của Chúa , mà là làm theo cảm xúc của người đàn ông .
# Ref : " Điều gì " không phải phản ánh tâm trí của Chúa nữa , mà theo dấu những cảm xúc bất an của con người .
# ----------------------------------------
# [58]
# EN : At the Headwaters itself , Shell Canada has plans to extract methane gas from coal seams that underly a million acres , fracking the coal with hundreds of millions of gallons of toxic chemicals , establishing perhaps as many as 6,000 wellheads , and eventually a network of roads and pipelines and flaring wellheads , all to generate methane gas that most likely will go east to fuel the expansion of the tar sands .
# Pred: Ở mặt trời , Canada có những kế hoạch hoá học để lấy khí metan từ các đường ống mà dưới hàng triệu hình vuông với hàng trăm triệu hoá chất độc hại của các hoá chất độc hại , có lẽ là 6,000 cây , và cuối cùng là một mạng lưới đường xá và các tuyến dầu mỏ , tất cả để sản xuất ra khí ga , để sản xuất ra lượng khí ga có thể đốt cho các hạt cát dầu .
# Ref : Ở thượng nguồn đó , Công ty dầu khí Canada có những kế hoạch trích xuất khí metan từ những vỉa than nằm sâu 1 triệu mẫu Anh dùng thuỷ lực bẻ gẫy than đá với hàng trăm triệu gallon chất thải độc hại tạo nên dường như 6000 đầu giếng và cuối cùng là 1 hệ thống đường và ống và và đầu giếng loe , tất cả nhằm tạo ra khí metan mà rất có thể đi về hướng Đông làm nhiên liệu cho sự mở rộng của cát dầu .
# ----------------------------------------
# [59]
# EN : That report was written by 620 scientists from 40 countries .
# Pred: Báo cáo đó được viết bởi 620 nhà khoa học từ 40 quốc gia .
# Ref : Nghiên cứu được viết bởi 620 nhà khoa học từ 40 quốc gia khác nhau .
# ----------------------------------------
# [60]
# EN : That you are in charge , and you 're going to tell people what to do next .
# Pred: Bạn chịu trách nhiệm , và bạn sẽ nói với mọi người điều cần làm tiếp theo .
# Ref : Bạn là người phụ trách . Và bạn sẽ nói cho những người khác biết phải làm gì tiếp theo .
# ----------------------------------------
# [61]
# EN : Anyway , I 'm clearly obsessed .
# Pred: Dù sao đi nữa , tôi bị ám ảnh .
# Ref : Dù sao đi nữa , tôi vẫn bị ám ảnh về vụ này
# ----------------------------------------
# [62]
# EN : It 's the roommate you can 't kick out . It 's the voice you can 't ignore .
# Pred: Nó là bạn không thể xé ra ngoài . Đó là giọng nói mà bạn không thể lờ đi .
# Ref : Nó ở ngay cạnh mà bạn không thể đuổi đi Nó là tiếng nói bạn không thể lảng tránh ,
# ----------------------------------------
# [63]
# EN : So , in 2006 , now it 's really time to have fun .
# Pred: Vì thế vào năm 2006 , giờ là thời điểm rất vui .
# Ref : Năm 2006 , đã đến lúc vui vẻ .
# ----------------------------------------
# [64]
# EN : Svante Pääbo : DNA clues to our inner neanderthal
# Pred: Svante dựa trên máy bay tự động
# Ref : Svante Paabo : Những manh mối về ADN của người Neanderthal trong chúng ta
# ----------------------------------------
# [65]
# EN : I went to Gates Lane Elementary School in Worcester , Massachusetts , and I had wonderful teachers there , most notably in first grade Mrs. Alisch .
# Pred: Tôi đã đến Los Angeles về trường Đại học California , Massachusetts , và tôi có những giáo viên tuyệt vời ở đó , không thể tin được đầu tiên ở trường trung học .
# Ref : Tôi học trường tiểu học Gates Lane ở Worcester , Massachusetts , và tôi đã có những giáo viên tuyệt vời , đặc biệt nhất là cô Alisch , cô giáo lớp 1 .
# ----------------------------------------
# [66]
# EN : What would it be like to be improving the human lot ?
# Pred: Sẽ thế nào khi được cải thiện nhiều người ?
# Ref : Điều gì sẽ cải thiện số phận con người ?
# ----------------------------------------
# [67]
# EN : And second , just as in a radio broadcast , you can communicate with many receivers at once .
# Pred: Và thứ hai , cũng như trong một phát thanh phát thanh radio , bạn có thể liên lạc với rất nhiều người cùng một lúc .
# Ref : Thứ hai , cũng như khi dùng sóng radio , bạn có thể giao tiếp với nhiều người nghe cùng một lúc .
# ----------------------------------------
# [68]
# EN : So let 's watch that . Nobody 's ever seen it .
# Pred: Hãy cùng xem . Không ai từng thấy .
# Ref : Vậy hãy xem nó . Chưa có ai từng được xem nó .
# ----------------------------------------
# [69]
# EN : And I 'm still on that mission .
# Pred: Và tôi vẫn đang trên sứ mệnh đó .
# Ref : Và bây giờ vẫn chưa thôi .
# ----------------------------------------
# [70]
# EN : In humans -- by the way , this is true for all mammals ; it 's true for other mammals -- and in humans , it got a lot worse .
# Pred: Trong con người -- nhân tiện , điều này đúng với tất cả các loài động vật có vú ; nó đúng với động vật có vú khác -- và trong con người , nó trở nên tồi tệ hơn .
# Ref : cho con người và cũng đúng cho mọi loài có vú , nó đúng cho các loài có vú , và ở con người , nó tệ hơn nhiều .
# ----------------------------------------
# [71]
# EN : You could inform legislation .
# Pred: Bạn có thể thông báo bản pháp .
# Ref : Bạn có thể thông báo cho chính quyền
# ----------------------------------------
# [72]
# EN : And you can see here that the flash of light has exactly the same effect .
# Pred: Và bạn có thể thấy ở đây rằng ánh sáng có hiệu ứng y hệt nhau .
# Ref : Và bạn có thể thấy ở đây , những chùm sáng cũng gây ra tác động tương tự .
# ----------------------------------------
# [73]
# EN : So what if you could do the same thing with a solar cell or a battery ?
# Pred: Vậy điều gì sẽ xảy ra nếu bạn có thể làm điều tương tự với pin mặt trời hay pin mặt trời ?
# Ref : Vậy sẽ ra sao nếu bạn có thể làm điều tương tự với pin mặt trời hoặc pin hoá học ?
# ----------------------------------------
# [74]
# EN : And it had , once it was in the air , some of this romance that I was in love with .
# Pred: Và một lần trong không khí , một số sự lãng mạn mà tôi yêu thích .
# Ref : và một khi nó đã ở trong không trung , nó có một vài điều lãng mạn mà tôi yêu thích .
# ----------------------------------------
# [75]
# EN : And that 's because it 's such an enraging , yet engaging place to be .
# Pred: Và đó là bởi vì nó là một nơi đầy đam mê , nhưng lại rất thú vị .
# Ref : Và đây hẳn là một nơi điên khùng nhưng cũng đầy hấp dẫn .
# ----------------------------------------
# [76]
# EN : We hid behind cars , running through the darkness that lay between the streetlights , boundless laughter ubiquitous across the pavement .
# Pred: Chúng tôi giấu những chiếc xe đằng sau xe chạy xuyên qua bóng tối nằm giữa những chiếc đèn đường , không dao động khắp nơi .
# Ref : Chúng tôi trốn sau những chiếc xe , chạy qua những chỗ tối giữa các cột đèn , cả một góc đường ngập tràn tiếng cười .
# ----------------------------------------
# [77]
# EN : So this is a cinder block , uncoated , and you can see that it 's porous , it absorbs water .
# Pred: Đây là một khối gạch , không may , và bạn có thể thấy đó là khối lọc nước , nó chứa nước .
# Ref : Đây là khối đá xỉ , trơn và bạn thấy nó rỗng , có thể hút nước .
# ----------------------------------------
# [78]
# EN : Now , what I don 't think is that Jensen got extremely lucky and happened to land in the one set of villages where technology made things better .
# Pred: Bây giờ , điều mà tôi không nghĩ là Jensen đã trở nên rất may mắn và đã xảy ra đất trong một trong những ngôi làng mà công nghệ làm ra những thứ tốt hơn .
# Ref : Tôi không nghĩ rằng Jensen đã may mắn và vô tình dẫn chứng đúng những ngôi làng mà ở đó công nghệ mang đến những kết quả tốt đẹp .
# ----------------------------------------
# [79]
# EN : It actually has a level of dexterity in its penis much akin to what we have with our hands .
# Pred: Nó thực sự có mức độ của các tổ chức phi lợi nhuận trong việc phân phối những gì chúng ta có bằng tay .
# Ref : Dương vật của nó linh hoạt như bàn tay con người .
# ----------------------------------------
# [80]
# EN : And the result is sort of gratifyingly perpetual .
# Pred: Và kết quả là sự phân chia .
# Ref : Cái kết quả là thứ gì đó như là sự mãn nguyện lâu dài .
# ----------------------------------------
# [81]
# EN : The life cycle impact of that lettuce is astronomical .
# Pred: Cuộc sống đã tác động của sự dao động đó là vô cùng lớn .
# Ref : Sự tác động của vòng đời cây cải này thật sự to lớn
# ----------------------------------------
# [82]
# EN : It 's a two-seat , single-engine airplane that works just like any other small airplane .
# Pred: Nó là một máy bay hai chiều , một máy bay chỉ hoạt động như bất kỳ máy bay nhỏ khác .
# Ref : Đó là một chiếc máy bay 2 chỗ ngồi , 1 động cơ và vận hành giống như những chiếc máy bay con khác .
# ----------------------------------------
# [83]
# EN : It made my building look sick .
# Pred: Nó đã làm cho tôi chăm sóc .
# Ref : Nó làm toà nhà của tôi trông gớm chết được .
# ----------------------------------------
# [84]
# EN : You 'd have to fill your entire parking space of one garage space just to give yourself four hours of battery back-up .
# Pred: Bạn sẽ phải điền toàn bộ không gian đỗ xe của bạn vào một trạm không gian để tự cho mình bốn giờ sau .
# Ref : Bạn phải nạp đầy toàn bộ khu vực đỗ xe của 1 gara chỉ để có 4 giờ pin dự trữ .
# ----------------------------------------
# [85]
# EN : And if you actually look in their brains , you see that they 're flooded with these neurotransmitters that are really good at inducing learning and plasticity , and the inhibitory parts haven 't come on yet .
# Pred: Và nếu bạn nhìn vào bộ não của chúng , bạn sẽ thấy chúng đang bị ngập tràn ngập những bộ phận dẫn truyền thần kinh rất giỏi trong việc học tập và nhựa dẻo , và những bộ phận bị đốt cháy .
# Ref : Nếu quan sát não chúng , bạn nhận ra rằng chúng chứa đầy những chất dẫn truyền thần kinh chất thúc đẩy sự học và độ dẻo dai , còn các phần ức chế chưa xuất hiện
# ----------------------------------------
# [86]
# EN : And then , again , my left hemisphere comes online and it says , " Hey ! You 've got to pay attention .
# Pred: Và rồi , một lần nữa , trái của tôi đi lên mạng và nói , " Này ! Bạn phải chú ý .
# Ref : Khi đó , não trái của tôi kết nối trở lại và nói , " Kìa ! Bà phải tập trung .
# ----------------------------------------
# [87]
# EN : I get a lot of really nice letters , lots of them .
# Pred: Tôi lấy rất nhiều những bức thư hay .
# Ref : mà tôi còn nhận được rất nhiều những lá thư tốt đẹp , rất nhiều rất nhiều .
# ----------------------------------------
# [88]
# EN : Or in a parallel universe , you find this information .
# Pred: Hay trong một vũ trụ song , bạn tìm thấy thông tin này .
# Ref : Hoặc trong trường hợp khác , bạn thấy thông tin này .
# ----------------------------------------
# [89]
# EN : When you 're having a four-inch needle inserted into your spine -- which was the procedure that this device 's data was about ; it was for pain management -- you 're shit scared ; you 're freaking out .
# Pred: Khi bạn có một cây kim tiêm được đặt vào trong tâm trạng của bạn -- đó là quy trình mà thiết bị này dữ liệu về sự quản lý , đó là về quản lý quản lý , bạn sợ ; bạn sợ hãi .
# Ref : Khi bạn bị một cây kim dài 4 inch đâm vào xương sống -- đó là quy trình chẩn đoán mà thiết bị này lưu dữ liệu ; để kiểm soát sự đau đớn -- bạn thấy hoảng hốt , bạn sợ phát khiếp .
# ----------------------------------------
# [90]
# EN : But you have to think evolutionarily , you have to think , what hard job that has to be done -- it 's dirty work , somebody 's got to do it -- is so important to give us such a powerful , inbuilt reward for it when we succeed .
# Pred: Nhưng bạn phải suy nghĩ theo một cách nào đó , bạn phải nghĩ rằng , những gì mà công việc phải làm -- đó là hiệu quả , một người nào đó phải làm việc đó -- rất quan trọng để cho chúng ta một phần thưởng mạnh mẽ , trong việc xây dựng lại khi chúng ta thành công .
# Ref : Nhưng các bạn phải nghĩ về nó theo cách của sự tiến hoá , các bạn phải nghĩ rằng ta phải làm sao đây -- đó là một việc " khó khăn " , nhưng ai đó phải làm nó thôi -- nó rất là quan trọng tại nó đem lại cho ta sức mạnh , một phần thưởng bên trong khi ta thành công .
# ----------------------------------------
# [91]
# EN : I said , " What ? "
# Pred: Tôi hỏi , " Cái gì ? "
# Ref : Tôi đã nói , " Cái gì ? "
# ----------------------------------------
# [92]
# EN : And what happened a month ago was that the Chinese company , Geely , they acquired the Volvo company , and then finally the Swedes understood that something big had happened in the world .
# Pred: Và điều xảy ra vào tháng trước là công ty Trung Quốc , Gee Alley , họ có công ty Volkman , và cuối cùng người Thuỵ Điển hiểu rằng có điều gì đó lớn xảy ra trên thế giới .
# Ref : Chuyện xảy ra một tháng trước một công ty Trung Quốc , Geely , đã chiếm được công ty Volvo . Chỉ đến lúc đó , người Thuỵ Điển mới biết rằng có chuyện gì đó rất hệ trọng đã xảy ra trên thế giới .
# ----------------------------------------
# [93]
# EN : Because sometimes , as Proust says , mystery is not about traveling to new places , but it 's about looking with new eyes .
# Pred: Bởi vì đôi khi , như Proust nói , bí ẩn không phải là đi du lịch đến những nơi mới , mà là về việc tìm kiếm những con mắt mới .
# Ref : Bởi vì đôi khi , như Proust nói , bí ẩn không phải là đi đến một nơi mới mẻ , mà nó là việc chúng ta nhìn sự vật với một cái nhìn mới .
# ----------------------------------------
# [94]
# EN : And here are the ducks again .
# Pred: Và đây là một lần nữa .
# Ref : Và đây là lại là những con vịt .
# ----------------------------------------
# [95]
# EN : I 'm going to talk about dinosaurs .
# Pred: Tôi sẽ nói về khủng long .
# Ref : Tôi sẽ nói về khủng long .
# ----------------------------------------
# [96]
# EN : We 're people , and we have problems .
# Pred: Chúng ta là những người , và chúng ta có những vấn đề .
# Ref : Chúng ta là con người , và chúng ta có những vấn đề .
# ----------------------------------------
# [97]
# EN : It sounds like a lot of money ; it is a lot of money .
# Pred: Nghe có vẻ như rất nhiều tiền .
# Ref : Nó trông có vẻ nhiều. thực sự đó là một số tiền khá lớn
# ----------------------------------------
# [98]
# EN : After a catastrophic car accident that left him in a coma , Simon Lewis found ways to recover -- physically and mentally -- beyond all expectations . At the INK Conference he tells how this remarkable story led him to concern over all threats to consciousness , and how to overcome them .
# Pred: Sau một tai nạn xe hơi bị tai nạn khi rời khỏi cơn hôn mê , Simon Lewis đã tìm ra cách phục hồi cơ thể -- và tinh thần -- vượt qua tất cả những kỳ vọng . Tại hội nghị này , ông kể câu chuyện đáng chú ý đến ông với ý thức về nhận thức , và làm thế nào để vượt qua chúng .
# Ref : Sau một tai nạn xe hơi thảm khốc khiến ông bị hôn mê , Simon Lewis đã tìm cách để phục hồi -- về cả thể chất và tinh thần -- hơn cả mong đợi . Tại Hội nghị INK nói về cách câu chuyện đáng nhớ này khiến mình quan tâm tới những đe doạ với trạng thái tỉnh táo , và làm cách nào để vượt qua chúng .
# ----------------------------------------
# [99]
# EN : There 's emotional contagion that takes place in human populations .
# Pred: Có những cảm xúc đã diễn ra trong quần thể con người .
# Ref : Có sự lây truyền về cảm xúc diễn ra trong xã hội loài người .
# ----------------------------------------
# [100]
# EN : Basically , listen to yourself .
# Pred: Đơn giản , hãy lắng nghe bản thân .
# Ref : Về cơ bản , hãy lắng nghe chính mình .
# ----------------------------------------

# %%
def translate_batch(texts, model, tokenizer, device=DEVICE, max_len=128):
    """
    Dịch một list các câu tiếng Anh sang tiếng Việt.
    """
    model.eval()
    # Tokenize hàng loạt
    batch = tokenizer(texts, return_tensors="pt", padding=True, truncation=True, max_length=128).to(device)
    src_ids = batch['input_ids']
    src_mask = batch['attention_mask'].bool()
    translations = []
    for i in range(src_ids.size(0)):
        with torch.no_grad():
            enc_out = model.enc(src_ids[i:i+1], src_mask[i:i+1])
        ys = torch.tensor([[tokenizer.bos_token_id]], device=device)
        for _ in range(max_len):
            S = ys.size(1)
            tmask = torch.tril(torch.ones((S, S), dtype=torch.bool, device=device)).unsqueeze(0)
            with torch.no_grad():
                dec_out = model.dec(ys, enc_out, src_mask[i:i+1], tmask)
                logits = model.out(dec_out)
            next_token = logits[:, -1, :].argmax(-1).item()
            ys = torch.cat([ys, torch.tensor([[next_token]], device=device)], dim=1)
            if next_token == tokenizer.eos_token_id:
                break
        out_ids = ys[0, 1:].tolist()
        translations.append(tokenizer.decode(out_ids, skip_special_tokens=True).strip())
    return translations

# ----------- TEST MULTI-SENTENCE -----------
sample_en = [
    "I want to go to sleep",
    "Good morning! Did you sleep well?",
    "Yesterday the stock market plunged almost five percent.",
    "She wonders whether artificial intelligence will ever surpass human creativity.",
    "Please, turn off the lights before you leave the laboratory.",
    "Although it rained heavily, the concert continued until midnight.",
    "The report, which was published in 2023, estimates that global CO₂ emissions hit 37.4 gigatons.",
    "Have you ever tried Vietnamese egg coffee?",
    "If we fail to act now, future generations will pay the price.",
    "NASA's James Webb telescope recently captured breathtaking images of distant galaxies.",
    "In my opinion, learning a new language is like opening an extra window on the world."
]

vi_translations = translate_batch(sample_en, model, tokenizer,
                                      "cuda", max_len=128)

print("\n--- Sample Translations ---")
for en, vi in zip(sample_en, vi_translations):
    print(f"EN: {en}")
    print(f"VI: {vi}\n")
# Out:
# --- Sample Translations ---
# EN: I want to go to sleep
# VI: Tôi muốn đi ngủ để ngủ .
#
# EN: Good morning! Did you sleep well?
# VI: Sáng sáng sớm , bạn có thể ngủ ngon lành mạnh .
#
# EN: Yesterday the stock market plunged almost five percent.
# VI: Có khoảng cách về thị trường chứng khoán hầu như hầu hết 5 %
#
# EN: She wonders whether artificial intelligence will ever surpass human creativity.
# VI: Cô ấy đã làm thay đổi trí thông minh nhân tạo có thể bao giờ sáng tạo của con người bằng sáng tạo
#
# EN: Please, turn off the lights before you leave the laboratory.
# VI: Hãy tắt những ánh sáng trước khi bạn rời phòng thí nghiệm .
#
# EN: Although it rained heavily, the concert continued until midnight.
# VI: Mặc dù nó đã được đánh giá cao hơn cả ngày hôm sau , cho đến khi người ta tiếp tục đến ngày hôm qua .
#
# EN: The report, which was published in 2023, estimates that global CO₂ emissions hit 37.4 gigatons.
# VI: Báo cáo của báo cáo đã được xuất bản trong 20.000 ước lượng khí thải toàn cầu mà các nhà cung cấp dịch vụ toàn cầu hoá .
#
# EN: Have you ever tried Vietnamese egg coffee?
# VI: Bạn đã bao giờ thử một quán cà phê bình quân đội .
#
# EN: If we fail to act now, future generations will pay the price.
# VI: Nếu chúng ta thất bại hiện nay sẽ phải làm cho tương lai sẽ trả giá thành giá .
#
# EN: NASA's James Webb telescope recently captured breathtaking images of distant galaxies.
# VI: NASA James Randi James Randi , gần đây là những hình ảnh của thiên hà xa xôi .
#
# EN: In my opinion, learning a new language is like opening an extra window on the world.
# VI: Trong quan điểm của tôi , học ngôn ngữ mới là mở một cái cửa sổ mở rộng thêm một thế giới .

# %%
# # --------- 1) Mount Google Drive --------- # sẽ yêu cầu bạn cho phép

# # --------- 2) Khai báo đường dẫn ----------
# SRC_CKPT      = '/content/ckpt'
# SRC_BACKUP    = '/content/backup_ckpt'

# DST_CKPT      = '/content/drive/MyDrive/NLP_final/NLP_final/ckpt'
# DST_BACKUP    = '/content/drive/MyDrive/NLP_final/NLP_final/backup_ckpt'

# import os, shutil

# # --------- 3) Tạo thư mục đích (nếu chưa có) ----------
# os.makedirs(DST_CKPT,   exist_ok=True)
# os.makedirs(DST_BACKUP, exist_ok=True)

# # --------- 4) Copy toàn bộ nội dung ----------
# def copy_tree(src, dst):
#     for root, dirs, files in os.walk(src):
#         rel   = os.path.relpath(root, src)
#         tgt_r = os.path.join(dst, rel) if rel != '.' else dst
#         os.makedirs(tgt_r, exist_ok=True)
#         for f in files:
#             shutil.copy2(os.path.join(root, f), os.path.join(tgt_r, f))

# copy_tree(SRC_CKPT,   DST_CKPT)
# copy_tree(SRC_BACKUP, DST_BACKUP)

# print("✅  Đã sao chép xong!  Check Drive của bạn nhé.")
# Out:
# ✅  Đã sao chép xong!  Check Drive của bạn nhé.
